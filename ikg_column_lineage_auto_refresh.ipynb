# %% [markdown]
# # IKG Column Lineage Auto Refresh
#
# Runs column-level lineage extraction for all SQL files under the configured GitLab path.
# Uses the same GitLab and Greenplum configuration as `ikg_table_lineage_auto_refresh.py` and writes:
# - `sandbox_prj_smart_insights.ikg_column_lineage_master_auto_refresh`
# - `ikg_column_lineage_master_auto_refresh_<timestamp>.xlsx`

# %%
# Run the auto-refresh script
# !python ikg_column_lineage_auto_refresh.py
